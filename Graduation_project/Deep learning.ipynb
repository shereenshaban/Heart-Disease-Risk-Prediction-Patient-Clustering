# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from scipy.stats import ttest_rel
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Embedding, Flatten, Concatenate
from tensorflow.keras.models import Model, Sequential

# %%
df = pd.read_csv(r"C:\Users\Amr essam\Downloads\archive (1)\cardio_train.csv", sep=";")
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
num_cols = ['age','height','weight','ap_hi','ap_lo']
cat_cols = ['gender','cholesterol','gluc','smoke','alco','active']
target_col = 'cardio'

# %%
X_num = df[num_cols].fillna(df[num_cols].median())
scaler = StandardScaler()
X_num = scaler.fit_transform(X_num)

# %%
X_cat = df[cat_cols].astype(str)
encoders = {}
for c in cat_cols:
    le = LabelEncoder()
    X_cat[c] = le.fit_transform(X_cat[c])
    encoders[c] = le

X_all = np.concatenate([X_num, X_cat.values], axis=1)
y = df[target_col].values

# %%
ae_input_dim = X_all.shape[1]
ae_input = Input(shape=(ae_input_dim,))
e1 = Dense(8, activation="relu")(ae_input)
b = Dense(4, activation="relu")(e1)
d1 = Dense(8, activation="relu")(b)
ae_output = Dense(ae_input_dim, activation="linear")(d1)
autoencoder = Model(ae_input, ae_output)
encoder = Model(ae_input, b)
autoencoder.compile(optimizer="adam", loss="mse")
autoencoder.fit(X_all, X_all, epochs=20, batch_size=32, verbose=0)
X_encoded = encoder.predict(X_all)
# Out:
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 2s 957us/step

# %%
X_final = np.concatenate([X_all, X_encoded], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(256, activation="relu", input_shape=(X_train.shape[1],)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(128, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# c:\Users\Amr essam\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6338 - loss: 0.6612 - val_accuracy: 0.6947 - val_loss: 0.5816
# Epoch 2/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7083 - loss: 0.5816 - val_accuracy: 0.7289 - val_loss: 0.5611
# Epoch 3/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7164 - loss: 0.5732 - val_accuracy: 0.7274 - val_loss: 0.5603
# Epoch 4/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7184 - loss: 0.5691 - val_accuracy: 0.7293 - val_loss: 0.5548
# Epoch 5/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7199 - loss: 0.5670 - val_accuracy: 0.7346 - val_loss: 0.5541
# Epoch 6/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7189 - loss: 0.5681 - val_accuracy: 0.7295 - val_loss: 0.5557
# Epoch 7/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7193 - loss: 0.5647 - val_accuracy: 0.7355 - val_loss: 0.5482
# Epoch 8/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7221 - loss: 0.5643 - val_accuracy: 0.7279 - val_loss: 0.5517
# Epoch 9/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7219 - loss: 0.5633 - val_accuracy: 0.7359 - val_loss: 0.5469
# Epoch 10/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7219 - loss: 0.5618 - val_accuracy: 0.6829 - val_loss: 0.5949
# Epoch 11/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7233 - loss: 0.5636 - val_accuracy: 0.7372 - val_loss: 0.5466
# Epoch 12/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7231 - loss: 0.5616 - val_accuracy: 0.7275 - val_loss: 0.5499
# Epoch 13/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7244 - loss: 0.5623 - val_accuracy: 0.7340 - val_loss: 0.5489
# Epoch 14/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7210 - loss: 0.5626 - val_accuracy: 0.7375 - val_loss: 0.5482
# Epoch 15/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7229 - loss: 0.5613 - val_accuracy: 0.7316 - val_loss: 0.5511
# Epoch 16/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7248 - loss: 0.5584 - val_accuracy: 0.7383 - val_loss: 0.5429
# Epoch 17/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7238 - loss: 0.5601 - val_accuracy: 0.7339 - val_loss: 0.5507
# Epoch 18/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7238 - loss: 0.5602 - val_accuracy: 0.7280 - val_loss: 0.5520
# Epoch 19/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7223 - loss: 0.5596 - val_accuracy: 0.7368 - val_loss: 0.5457
# Epoch 20/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7237 - loss: 0.5605 - val_accuracy: 0.7301 - val_loss: 0.5520
# Epoch 21/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7234 - loss: 0.5602 - val_accuracy: 0.7302 - val_loss: 0.5492
# Epoch 22/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7240 - loss: 0.5591 - val_accuracy: 0.7304 - val_loss: 0.5479
# Epoch 23/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7237 - loss: 0.5588 - val_accuracy: 0.7333 - val_loss: 0.5478
# Epoch 24/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7248 - loss: 0.5596 - val_accuracy: 0.7365 - val_loss: 0.5421
# Epoch 25/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7271 - loss: 0.5584 - val_accuracy: 0.7340 - val_loss: 0.5457
# Epoch 26/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7212 - loss: 0.5593 - val_accuracy: 0.7312 - val_loss: 0.5470
# Epoch 27/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7257 - loss: 0.5576 - val_accuracy: 0.7364 - val_loss: 0.5460
# Epoch 28/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7260 - loss: 0.5591 - val_accuracy: 0.7365 - val_loss: 0.5444
# Epoch 29/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7259 - loss: 0.5584 - val_accuracy: 0.7328 - val_loss: 0.5507
# Epoch 30/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7242 - loss: 0.5586 - val_accuracy: 0.7381 - val_loss: 0.5471
# Epoch 31/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7255 - loss: 0.5581 - val_accuracy: 0.7362 - val_loss: 0.5444
# Epoch 32/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7252 - loss: 0.5577 - val_accuracy: 0.7347 - val_loss: 0.5467
# Epoch 33/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7248 - loss: 0.5579 - val_accuracy: 0.7293 - val_loss: 0.5500
# Epoch 34/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7254 - loss: 0.5579 - val_accuracy: 0.7357 - val_loss: 0.5434
# Epoch 35/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7246 - loss: 0.5589 - val_accuracy: 0.7340 - val_loss: 0.5457
# Epoch 36/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7240 - loss: 0.5558 - val_accuracy: 0.7332 - val_loss: 0.5472
# Epoch 37/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7256 - loss: 0.5563 - val_accuracy: 0.7346 - val_loss: 0.5512
# Epoch 38/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7266 - loss: 0.5566 - val_accuracy: 0.7364 - val_loss: 0.5438
# Epoch 39/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7243 - loss: 0.5576 - val_accuracy: 0.7351 - val_loss: 0.5440
# Epoch 40/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7247 - loss: 0.5579 - val_accuracy: 0.7331 - val_loss: 0.5511
# Epoch 41/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7241 - loss: 0.5590 - val_accuracy: 0.7371 - val_loss: 0.5451
# Epoch 42/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7263 - loss: 0.5564 - val_accuracy: 0.7390 - val_loss: 0.5450
# Epoch 43/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7252 - loss: 0.5566 - val_accuracy: 0.7346 - val_loss: 0.5442
# Epoch 44/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7242 - loss: 0.5573 - val_accuracy: 0.7375 - val_loss: 0.5459
# Epoch 45/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7259 - loss: 0.5575 - val_accuracy: 0.7361 - val_loss: 0.5512
# Epoch 46/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7252 - loss: 0.5564 - val_accuracy: 0.7307 - val_loss: 0.5507
# Epoch 47/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7252 - loss: 0.5570 - val_accuracy: 0.7341 - val_loss: 0.5533
# Epoch 48/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7258 - loss: 0.5581 - val_accuracy: 0.7374 - val_loss: 0.5497
# Epoch 49/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7261 - loss: 0.5572 - val_accuracy: 0.7370 - val_loss: 0.5501
# Epoch 50/50
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7260 - loss: 0.5557 - val_accuracy: 0.7378 - val_loss: 0.5451

# %%
pred_dnn = model.predict(X_test).flatten()
auc_dnn = roc_auc_score(y_test, pred_dnn)
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
rf = RandomForestClassifier(n_estimators=300, random_state=42)
rf.fit(X_train, y_train)
pred_rf = rf.predict_proba(X_test)[:,1]
auc_rf = roc_auc_score(y_test, pred_rf)

# %%
t_stat, p_val = ttest_rel(pred_dnn, pred_rf)

print("AUC DNN:", auc_dnn)
print("AUC RF:", auc_rf)
print("t-test:", t_stat, p_val)
# Out:
# AUC DNN: 0.801511641177068
# AUC RF: 0.7768229563776677
# t-test: 13.595685426210943 7.828325674746107e-42
